# %% [markdown]
# # 06 — Threshold Tuning
#
# Sweep thresholds against a business cost matrix (false-negative cost vs false-positive cost). Pick the optimal cutoff and write it back to `config.yaml`.
